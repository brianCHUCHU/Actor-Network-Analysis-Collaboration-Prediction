# %% [markdown]
# # Setup

# %%
import random
import numpy as np
from tqdm import tqdm
import os
from datetime import datetime

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import torch
from torch.nn import (ModuleList, Linear, Embedding, ReLU, 
                      LazyBatchNorm1d as LBN)
from torch.nn import BCEWithLogitsLoss, Sigmoid
import torch.nn.functional as F
from torch_geometric.utils import subgraph
from torch_geometric.data import Data
from torch_geometric.transforms import RandomLinkSplit
from torch_geometric.loader import LinkNeighborLoader
from torch_geometric.nn import GCNConv

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# %%
def set_seed(seed: int=42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    print("**** The seed has been initialized ****")
    return None
set_seed()
# Out:
# **** The seed has been initialized ****

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Data Preprocessing
#
# [*Ref: A tour of PyG’s data loaders*](https://medium.com/stanford-cs224w/a-tour-of-pygs-data-loaders-9f2384e48f8f)
#
# [*MovieLens & LinkNeighborLoader*](https://colab.research.google.com/drive/1GrAxHyZCZ13jpTkMy9vVO_v_U9nHDdvB)

# %%
#TODO:change the root path
folder = '../SEAL_OGB/dataset/movie_actor'
filename = 'movie_transformed.pt'
data = torch.load(os.path.join(folder, filename))
all_pos_edges = torch.cat([
    data.train_pos_edge_index,
    data.val_pos_edge_index,
    data.test_pos_edge_index
    ],
    dim=1
)
all_pos_edges.size()
# Out:
# torch.Size([2, 1313])

# %%
data
# Out:
# Data(x=[1942, 2], x_stat=[1942, 5], train_neg_edge_index=[2, 1051], val_pos_edge_index=[2, 131], test_pos_edge_index=[2, 131], train_pos_edge_index=[2, 1051], train_neg_adj_mask=[1942, 1942], val_neg_edge_index=[2, 131], test_neg_edge_index=[2, 131])

# %% [markdown]
# # Data Preprocessing

# %%
# utils
def get_pos_edges(batch_edge_index, all_pos_edges):
    mask = []
    for link in batch_edge_index.t():
        if link in all_pos_edges.t():
            mask.append(True)
        else:
            mask.append(False)
    batch_pos_edges = torch.stack([
        batch_edge_index[0][mask],
        batch_edge_index[1][mask]
        ], dim=0
        )
    return batch_pos_edges

def get_edge_mask(edge_index, all_pos_edges):
    mask = torch.zeros(1313, dtype=bool)
    for link in edge_index.t():
        tmp = (all_pos_edges.t() == link)
        idx = int((tmp[:, 0] * tmp[:, 1]).nonzero(as_tuple=True)[0])
        mask[idx] = True
    return mask

train_mask = get_edge_mask(data.train_pos_edge_index, all_pos_edges)
test_mask = get_edge_mask(data.test_pos_edge_index, all_pos_edges)

# %% [markdown]
# ## Node2Vec
# [*Ref: node2vec pytorch geometric*](https://juejin.cn/s/node2vec%20pytorch%20geometric)

# %%
from torch_geometric.nn import Node2Vec
torch.manual_seed(0)
EMBEDDING_DIM = 64

# Initialize Node2Vec
model = Node2Vec(all_pos_edges, embedding_dim=EMBEDDING_DIM, walk_length=10,
                 context_size=3, walks_per_node=20, num_negative_samples=1,
                 p=0.8, q=0.3, sparse=True)

# Train model
loader = model.loader(batch_size=128, shuffle=True)
optimizer = torch.optim.SparseAdam(model.parameters(), lr=0.01)
model.train()
for epoch in range(1, 101):
    total_loss = 0
    for pos_rw, neg_rw in loader:
        optimizer.zero_grad()
        loss = model.loss(pos_rw, neg_rw)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print('Epoch: {:02d}, Loss: {:.4f}'.format(epoch, total_loss / len(loader)))

z = model()
node_embeddings = z.detach().cpu()
node_embeddings.size()
# Out:
# Epoch: 01, Loss: 3.5137
# Epoch: 02, Loss: 3.0573
# Epoch: 03, Loss: 2.6701
# Epoch: 04, Loss: 2.3868
# Epoch: 05, Loss: 2.1373
# Epoch: 06, Loss: 1.9191
# Epoch: 07, Loss: 1.7372
# Epoch: 08, Loss: 1.5801
# Epoch: 09, Loss: 1.4490
# Epoch: 10, Loss: 1.3358
# Epoch: 11, Loss: 1.2353
# Epoch: 12, Loss: 1.1495
# Epoch: 13, Loss: 1.0781
# Epoch: 14, Loss: 1.0193
# Epoch: 15, Loss: 0.9683
# Epoch: 16, Loss: 0.9314
# Epoch: 17, Loss: 0.8960
# Epoch: 18, Loss: 0.8691
# Epoch: 19, Loss: 0.8473
# Epoch: 20, Loss: 0.8307
# Epoch: 21, Loss: 0.8154
# Epoch: 22, Loss: 0.8032
# Epoch: 23, Loss: 0.7939
# Epoch: 24, Loss: 0.7859
# Epoch: 25, Loss: 0.7798
# Epoch: 26, Loss: 0.7737
# Epoch: 27, Loss: 0.7710
# Epoch: 28, Loss: 0.7672
# Epoch: 29, Loss: 0.7638
# Epoch: 30, Loss: 0.7602
# Epoch: 31, Loss: 0.7583
# Epoch: 32, Loss: 0.7564
# Epoch: 33, Loss: 0.7544
# Epoch: 34, Loss: 0.7537
# Epoch: 35, Loss: 0.7512
# Epoch: 36, Loss: 0.7496
# Epoch: 37, Loss: 0.7490
# Epoch: 38, Loss: 0.7485
# Epoch: 39, Loss: 0.7472
# Epoch: 40, Loss: 0.7451
# Epoch: 41, Loss: 0.7454
# Epoch: 42, Loss: 0.7449
# Epoch: 43, Loss: 0.7441
# Epoch: 44, Loss: 0.7425
# Epoch: 45, Loss: 0.7426
# Epoch: 46, Loss: 0.7422
# Epoch: 47, Loss: 0.7418
# Epoch: 48, Loss: 0.7419
# Epoch: 49, Loss: 0.7405
# Epoch: 50, Loss: 0.7398
# Epoch: 51, Loss: 0.7402
# Epoch: 52, Loss: 0.7392
# Epoch: 53, Loss: 0.7395
# Epoch: 54, Loss: 0.7386
# Epoch: 55, Loss: 0.7392
# Epoch: 56, Loss: 0.7389
# Epoch: 57, Loss: 0.7379
# Epoch: 58, Loss: 0.7377
# Epoch: 59, Loss: 0.7375
# Epoch: 60, Loss: 0.7370
# Epoch: 61, Loss: 0.7374
# Epoch: 62, Loss: 0.7369
# Epoch: 63, Loss: 0.7358
# Epoch: 64, Loss: 0.7372
# Epoch: 65, Loss: 0.7363
# Epoch: 66, Loss: 0.7364
# Epoch: 67, Loss: 0.7368
# Epoch: 68, Loss: 0.7364
# Epoch: 69, Loss: 0.7364
# Epoch: 70, Loss: 0.7358
# Epoch: 71, Loss: 0.7366
# Epoch: 72, Loss: 0.7353
# Epoch: 73, Loss: 0.7359
# Epoch: 74, Loss: 0.7351
# Epoch: 75, Loss: 0.7357
# Epoch: 76, Loss: 0.7356
# Epoch: 77, Loss: 0.7350
# Epoch: 78, Loss: 0.7356
# Epoch: 79, Loss: 0.7353
# Epoch: 80, Loss: 0.7353
# Epoch: 81, Loss: 0.7355
# Epoch: 82, Loss: 0.7345
# Epoch: 83, Loss: 0.7350
# Epoch: 84, Loss: 0.7348
# Epoch: 85, Loss: 0.7354
# Epoch: 86, Loss: 0.7352
# Epoch: 87, Loss: 0.7346
# Epoch: 88, Loss: 0.7354
# Epoch: 89, Loss: 0.7353
# Epoch: 90, Loss: 0.7356
# Epoch: 91, Loss: 0.7351
# Epoch: 92, Loss: 0.7345
# Epoch: 93, Loss: 0.7344
# Epoch: 94, Loss: 0.7349
# Epoch: 95, Loss: 0.7345
# Epoch: 96, Loss: 0.7352
# Epoch: 97, Loss: 0.7349
# Epoch: 98, Loss: 0.7346
# Epoch: 99, Loss: 0.7347
# Epoch: 100, Loss: 0.7347
# torch.Size([1942, 64])

# %%
torch.save(node_embeddings, 'node_embeddings')

# %% [markdown]
# ## For Dataloader

# %%
def prepare_data(data: Data, mode: str) -> Data:
    d = data.clone().detach()
    if mode == 'train':
        d.edge_index = torch.cat([
            data.train_pos_edge_index,
            data.train_neg_edge_index
            ],
            dim=1
        )
        d.edge_label_index = d.edge_index.clone()
        pos_cnt = data.train_pos_edge_index.size(1)
        neg_cnt = data.train_neg_edge_index.size(1)
        d.edge_label = torch.cat([torch.ones(pos_cnt), torch.zeros(neg_cnt)])
    elif mode == 'valid':
        d.edge_index = torch.cat([
            data.val_pos_edge_index,
            data.val_neg_edge_index
            ],
            dim=1
        )
        d.edge_label_index = d.edge_index.clone()
        pos_cnt = data.val_pos_edge_index.size(1)
        neg_cnt = data.val_neg_edge_index.size(1)
        d.edge_label = torch.cat([torch.ones(pos_cnt), torch.zeros(neg_cnt)])
    elif mode == 'test':
        d.edge_index = torch.cat([
            data.test_pos_edge_index,
            data.test_neg_edge_index
            ],
            dim=1
        )
        d.edge_label_index = d.edge_index.clone()
        pos_cnt = data.test_pos_edge_index.size(1)
        neg_cnt = data.test_neg_edge_index.size(1)
        d.edge_label = torch.cat([torch.ones(pos_cnt), torch.zeros(neg_cnt)])
    else: # all
        d.edge_index = torch.cat([
            data.train_pos_edge_index,
            data.val_pos_edge_index,
            data.test_pos_edge_index,
            data.train_neg_edge_index,
            data.val_neg_edge_index,
            data.test_neg_edge_index
            ],
            dim=1
        )
        d.edge_label_index = d.edge_index.clone()
        pos_cnt = data.train_pos_edge_index.size(1) + data.val_pos_edge_index.size(1) + data.test_pos_edge_index.size(1)
        neg_cnt = data.train_neg_edge_index.size(1) + data.val_neg_edge_index.size(1) + data.test_neg_edge_index.size(1)
        d.edge_label = torch.cat([torch.ones(pos_cnt), torch.zeros(neg_cnt)])
    
    # clean output
    del d.train_pos_edge_index
    del d.train_neg_edge_index
    del d.val_pos_edge_index
    del d.val_neg_edge_index
    del d.test_pos_edge_index
    del d.test_neg_edge_index
    del d.train_neg_adj_mask

    return d

# %% [markdown]
# ## Model Hyper-Parameter Setting

# %%
#TODO: Model Hyper-Parameters
# dataloader
BATCH_SIZE = 64
NUM_NEIGHBORS = [5, 5]

# GCN
HIDDEN_CHANNEL = 64
NUM_LAYERS = 2
USE_GRAPH_STAT = False
DROPOUT = 0.3

# Optimization
EPOCHS = 300
LR = 1e-4
PATIENCE = 80

MODEL_PATH = './model_states'

# %%
torch.manual_seed(0)
train_data = prepare_data(data, 'train')
valid_data = prepare_data(data, 'valid')
test_data = prepare_data(data, 'test')

print(train_data)
print(valid_data)
print(test_data)

train_loader = LinkNeighborLoader(train_data,
                                  num_neighbors=NUM_NEIGHBORS,
                                  batch_size=BATCH_SIZE,
                                  edge_label=train_data.edge_label,
                                  edge_label_index=train_data.edge_label_index,
                                  # these are only set for train!
                                  shuffle=True)
val_loader   = LinkNeighborLoader(valid_data,
                                  num_neighbors=NUM_NEIGHBORS,
                                  batch_size=BATCH_SIZE,
                                  edge_label=valid_data.edge_label,
                                  edge_label_index=valid_data.edge_label_index,
                                  shuffle=True)
test_loader  = LinkNeighborLoader(test_data,
                                  num_neighbors=NUM_NEIGHBORS,
                                  batch_size=BATCH_SIZE,
                                  edge_label=test_data.edge_label,
                                  edge_label_index=test_data.edge_label_index,
                                  shuffle=True)
# Out:
# Data(x=[1942, 2], x_stat=[1942, 5], edge_index=[2, 2102], edge_label_index=[2, 2102], edge_label=[2102])
# Data(x=[1942, 2], x_stat=[1942, 5], edge_index=[2, 262], edge_label_index=[2, 262], edge_label=[262])
# Data(x=[1942, 2], x_stat=[1942, 5], edge_index=[2, 262], edge_label_index=[2, 262], edge_label=[262])

# %% [markdown]
# # Model

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, num_layers, use_graph_stat=False, 
                 dropout=0.5, feature_dim = 2, graph_stat_dim = 3, node_embeddings = node_embeddings):
        super(GCN, self).__init__()
        self.use_graph_stat = use_graph_stat
        self.node_embeddings = node_embeddings
        self.actor_emb = Embedding(1942, hidden_channels)

        initial_channels = hidden_channels
        initial_channels += feature_dim
        # if graph stats included
        if self.use_graph_stat:
            initial_channels += graph_stat_dim

        # self.batchnorm = LBN(feature_dim + graph_stat_dim) if use_graph_stat else LBN(feature_dim)
        self.convs = ModuleList()
        self.convs.append(GCNConv(initial_channels, hidden_channels))
        for _ in range(num_layers - 1):
            self.convs.append(GCNConv(hidden_channels, hidden_channels))

        self.dropout = dropout
        # self.lin1 = Linear(hidden_channels, hidden_channels)
        # self.lin2 = Linear(hidden_channels, 1)
        self.lin = Linear(hidden_channels, 1)

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()

    def forward(self, x, node_ids, edge_index, edge_label_index, edge_weight=None):
        # x = self.batchnorm(x)
        # x = torch.cat([self.actor_emb(node_ids), x], dim=-1)
        x = torch.cat([self.node_embeddings[node_ids], x], dim=-1)
        
        pos_edges = get_pos_edges(edge_index, all_pos_edges)
        # edge_index, _ = subgraph(node_ids, edge_index)
        for conv in self.convs[:-1]:
            x = conv(x, pos_edges, edge_weight)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.convs[-1](x, edge_index, edge_weight)
        
        x_src = x[edge_label_index[0]]
        x_dst = x[edge_label_index[1]]
        x = (x_src * x_dst) # node pair
        # x = F.relu(self.lin1(x))
        # x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.lin(x)
        
        return x

# %% [markdown]
# ### Train

# %%
# Model Config
model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
parameters = list(model.parameters())
optimizer = torch.optim.Adam(params=parameters, lr=LR)
loss_fn = BCEWithLogitsLoss()

# %%
def train(model, train_loader=train_loader, val_loader=val_loader, verbose=True):
    print(f"***** Epochs: {EPOCHS}, Batch_size: {BATCH_SIZE}, Use_graph_stat: {USE_GRAPH_STAT}, Num_neighbors: {NUM_NEIGHBORS} *****")
    print(f"***** Num_layers: {NUM_LAYERS}, Hidden_channels: {HIDDEN_CHANNEL}, Dropout: {DROPOUT}, lr: {LR} *****\n")
    set_seed()
    torch.manual_seed(0)

    model.train()
    THRESHOLD = 0.5
    trigger = 0
    best_valid_auc = 0
    for epoch_num in range(1, EPOCHS+1):
        train_losses = []
        y_pred_tensors = torch.tensor([])
        y_true_tensors = torch.tensor([])

        total_loss = 0
        pbar = tqdm(train_loader, ncols=70, disable=(not verbose))
        for batch_data in pbar:
            batch_data = batch_data.to(DEVICE)
            optimizer.zero_grad()
            x = data.x_stat if USE_GRAPH_STAT else data.x #TODO: use all data for message passing

            # node_ids = torch.LongTensor(range(data.num_nodes))
            logits = model(batch_data.x, batch_data.n_id, batch_data.edge_index, batch_data.edge_label_index)
            loss = loss_fn(logits.view(-1), batch_data.edge_label)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

            logits = Sigmoid()(logits.view(-1))
            logits[logits >= THRESHOLD] = 1
            logits[logits < THRESHOLD] = 0
            y_pred_tensors = torch.cat([y_pred_tensors, logits.cpu()])
            y_true_tensors = torch.cat([y_true_tensors, batch_data.edge_label.cpu()])

        avg_loss = round(total_loss / len(train_loader), 3)
        train_losses.append(avg_loss)
        train_auc = roc_auc_score(y_true_tensors.detach(), y_pred_tensors.detach())

        # ======================================================
        # Set the state of the model to "Evaluation"
        model.eval()

        valid_true = torch.tensor([])
        valid_pred = torch.tensor([])

        # Validation
        with torch.no_grad():
            for valid_batch_data in tqdm(val_loader, ncols=70, disable=(not verbose)):
                valid_batch_data = valid_batch_data.to(DEVICE)
                x = valid_batch_data.x_stat if USE_GRAPH_STAT else valid_batch_data.x
                logits = model(x, valid_batch_data.n_id, valid_batch_data.edge_index, valid_batch_data.edge_label_index)

                logits = Sigmoid()(logits.view(-1))
                logits[logits >= THRESHOLD] = 1
                logits[logits < THRESHOLD] = 0
                valid_pred = torch.cat([valid_pred, logits.cpu()])
                valid_true = torch.cat([valid_true, valid_batch_data.edge_label.cpu()])
            
            valid_auc = roc_auc_score(valid_true.detach(), valid_pred.detach())
        
        if epoch_num % 10 == 0:
            print(
                f"Epochs: {epoch_num}  | Train Loss: {avg_loss: .3f} | Train AUC: {train_auc: .3f} | Valid AUC: {valid_auc: .3f}  --best: {best_valid_auc: .3f}"
            )
        
        # early-stopping
        if valid_auc <= best_valid_auc:
            trigger += 1
        else:
            trigger = 0
            best_valid_auc = valid_auc
        if trigger == PATIENCE:
            print(f"early stopping at epoch: {epoch_num}")
            break

    # save model
    time = datetime.now().strftime('%m-%d_%H:%M')
    torch.save(model.state_dict(), os.path.join(MODEL_PATH, f'model_checkpoint_{round(best_valid_auc, 3)}'))

    return model

# %%
def test(model, test_loader=test_loader):
    torch.manual_seed(0)
    model.eval()

    test_loss = 0
    test_true = torch.tensor([])
    test_pred = torch.tensor([])
    # Validation
    THRESHOLD = 0.5
    with torch.no_grad():
        for test_batch_data in test_loader:
            test_batch_data = test_batch_data.to(DEVICE)
            x = test_batch_data.x_stat if USE_GRAPH_STAT else test_batch_data.x
            logits = model(x, test_batch_data.n_id, test_batch_data.edge_index, test_batch_data.edge_label_index)
            loss = loss_fn(logits.view(-1), test_batch_data.edge_label)
            test_loss += loss

            logits = Sigmoid()(logits.view(-1))
            logits[logits >= THRESHOLD] = 1
            logits[logits < THRESHOLD] = 0
            test_pred = torch.cat([test_pred, logits.cpu()])
            test_true = torch.cat([test_true, test_batch_data.edge_label.cpu()])
        
        test_auc = roc_auc_score(test_true.detach(), test_pred.detach())
        avg_loss = test_loss / len(test_loader)
    print(f"Test Loss: {avg_loss: .3f} | Test AUC: {test_auc: .3f}")

    return test_true, test_pred

# %%
# Start training!
GCN_model = train(model, verbose=False)
print('='*20, '\n')

# Start testing!
test_true, test_pred = test(GCN_model)
# Out:
# ***** Epochs: 300, Batch_size: 64, Use_graph_stat: False, Num_neighbors: [5, 5] *****
# ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.0001 *****
#
# **** The seed has been initialized ****
# Epochs: 10  | Train Loss:  0.593 | Train AUC:  0.667 | Valid AUC:  0.649  --best:  0.668
# Epochs: 20  | Train Loss:  0.594 | Train AUC:  0.661 | Valid AUC:  0.668  --best:  0.668
# Epochs: 30  | Train Loss:  0.591 | Train AUC:  0.668 | Valid AUC:  0.672  --best:  0.668
# Epochs: 40  | Train Loss:  0.591 | Train AUC:  0.660 | Valid AUC:  0.653  --best:  0.672
# Epochs: 50  | Train Loss:  0.594 | Train AUC:  0.664 | Valid AUC:  0.656  --best:  0.672
# Epochs: 60  | Train Loss:  0.592 | Train AUC:  0.662 | Valid AUC:  0.645  --best:  0.672
# Epochs: 70  | Train Loss:  0.596 | Train AUC:  0.658 | Valid AUC:  0.653  --best:  0.672
# Epochs: 80  | Train Loss:  0.596 | Train AUC:  0.662 | Valid AUC:  0.653  --best:  0.672
# Epochs: 90  | Train Loss:  0.590 | Train AUC:  0.659 | Valid AUC:  0.649  --best:  0.672
# Epochs: 100  | Train Loss:  0.592 | Train AUC:  0.661 | Valid AUC:  0.649  --best:  0.672
# Epochs: 110  | Train Loss:  0.594 | Train AUC:  0.659 | Valid AUC:  0.653  --best:  0.672
# early stopping at epoch: 110
# ====================
#
# Test Loss:  0.571 | Test AUC:  0.676

# %%
# Current Best
# n2v: p=0.8, q=0.3, walk_length=10, walks=20, context=3
# ***** Epochs: 300, Batch_size: 64, Use_graph_stat: False, Num_neighbors: [5, 5] *****
# ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.0001 *****

model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
model_state = torch.load(os.path.join(MODEL_PATH, 'model_checkpoint_best_0.676'))
model.load_state_dict(model_state)
test_pred, test_true = test(model)
# Out:
# Test Loss:  0.571 | Test AUC:  0.676

# %%
# # Current Best
# # n2v: p=0.8, q=0.3, walk_length=10, walks=20, context=3
# # ***** Epochs: 300, Batch_size: 128, Use_graph_stat: False, Num_neighbors: [5, 5] *****
# # ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.0001 *****

# model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
# model_state = torch.load(os.path.join(MODEL_PATH, 'model_checkpoint_best_0.668'))
# model.load_state_dict(model_state)
# test_pred, test_true = test(model)
# Out:
# Test Loss:  0.556 | Test AUC:  0.668

# %%
# # Current Best
# # n2v: p=0.8, q=0.3, walk_length=10, walks=20, context=3
# # ***** Epochs: 300, Batch_size: 128, Use_graph_stat: False, Num_neighbors: [100, 100] *****
# # ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.005 *****

# model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
# model_state = torch.load(os.path.join(MODEL_PATH, 'model_checkpoint_best_0.653'))
# model.load_state_dict(model_state)
# test_pred, test_true = test(model)
# Out:
# Test Loss:  2.577 | Test AUC:  0.653

# %%
# # Current Best
# # n2v: p=0.8, q=0.3, walk_length=10, walks=20, context=3
# # ***** Epochs: 300, Batch_size: 128, Use_graph_stat: False, Num_neighbors: [5, 5, 5] *****
# # ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.0001 *****

# model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
# model_state = torch.load(os.path.join(MODEL_PATH, 'model_checkpoint_best_0.641'))
# model.load_state_dict(model_state)
# test_pred, test_true = test(model)
# Out:
# Test Loss:  0.558 | Test AUC:  0.641

# %%
# # Current Best
# # n2v: p=0.8, q=0.3, walk_length=10, walks=20, context=3
# # ***** Epochs: 300, Batch_size: 128, Use_graph_stat: False, Num_neighbors: [5, 5, 5] *****
# # ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.0001 *****

# model = GCN(64, 2, USE_GRAPH_STAT, 0.3)
# model_state = torch.load(os.path.join(MODEL_PATH, 'model_checkpoint_best_0.626'))
# model.load_state_dict(model_state)
# test_pred, test_true = test(model)
# Out:
# Test Loss:  0.563 | Test AUC:  0.626

# %% [markdown]
# ### Features + Graph_Stat

# %%
# # GCN
# HIDDEN_CHANNEL = 128
# NUM_LAYERS = 2
# USE_GRAPH_STAT = True
# DROPOUT = 0.3

# # Optimization
# EPOCHS = 300
# LR = 1e-4
# MOMENTUM = 0.9
# PATIENCE = 30

# # Model Config
# model_stat = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
# parameters = list(model_stat.parameters())
# # optimizer = torch.optim.SGD(params=parameters, lr=LR, momentum=MOMENTUM)
# optimizer = torch.optim.Adam(params=parameters, lr=LR)
# loss_fn = BCEWithLogitsLoss()

# %%
# GCN_v2 = train(model_stat, verbose=False)
# Out:
# ***** Epochs: 300, Batch_size: 64, Use_graph_stat: True *****
# ***** Num_layers: 2, Hidden_channels: 128, Dropout: 0.3, lr: 0.0001 *****
#
# **** The seed has been initialized ****
# Epochs: 10  | Train Loss:  0.654 | Train AUC:  0.562 | Valid AUC:  0.561  --best: 0.549618320610687
# Epochs: 20  | Train Loss:  0.612 | Train AUC:  0.596 | Valid AUC:  0.519  --best: 0.5610687022900763
# Epochs: 30  | Train Loss:  0.556 | Train AUC:  0.656 | Valid AUC:  0.542  --best: 0.5763358778625953
# Epochs: 40  | Train Loss:  0.486 | Train AUC:  0.734 | Valid AUC:  0.569  --best: 0.6068702290076337
# Epochs: 50  | Train Loss:  0.407 | Train AUC:  0.794 | Valid AUC:  0.550  --best: 0.6068702290076337
# Epochs: 60  | Train Loss:  0.345 | Train AUC:  0.836 | Valid AUC:  0.550  --best: 0.6068702290076337
# early stopping at epoch: 66

# %% [markdown]
# # Inference

# %%
# Dataloader for whole dataset
torch.manual_seed(0)
all_data = prepare_data(data, 'all')
print(all_data)

all_data_loader = LinkNeighborLoader(all_data,
                                  num_neighbors=NUM_NEIGHBORS,
                                  batch_size=BATCH_SIZE,
                                  edge_label=all_data.edge_label,
                                  edge_label_index=all_data.edge_label_index,
                                  shuffle=True)

# Model Config
model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
parameters = list(model.parameters())
optimizer = torch.optim.Adam(params=parameters, lr=LR)
loss_fn = BCEWithLogitsLoss()

# Start training!
GCN_final_model = train(model, train_loader=all_data_loader, verbose=False)
print('='*20, '\n')
print("*** training completed! ***")
# Out:
# Data(x=[1942, 2], x_stat=[1942, 5], edge_index=[2, 2626], edge_label_index=[2, 2626], edge_label=[2626])
# ***** Epochs: 300, Batch_size: 64, Use_graph_stat: False, Num_neighbors: [5, 5] *****
# ***** Num_layers: 2, Hidden_channels: 64, Dropout: 0.3, lr: 0.0001 *****
#
# **** The seed has been initialized ****
# Epochs: 10  | Train Loss:  0.677 | Train AUC:  0.575 | Valid AUC:  0.592  --best:  0.611
# Epochs: 20  | Train Loss:  0.658 | Train AUC:  0.597 | Valid AUC:  0.618  --best:  0.645
# Epochs: 30  | Train Loss:  0.663 | Train AUC:  0.594 | Valid AUC:  0.649  --best:  0.656
# Epochs: 40  | Train Loss:  0.652 | Train AUC:  0.607 | Valid AUC:  0.637  --best:  0.668
# Epochs: 50  | Train Loss:  0.648 | Train AUC:  0.615 | Valid AUC:  0.668  --best:  0.683
# Epochs: 60  | Train Loss:  0.658 | Train AUC:  0.610 | Valid AUC:  0.672  --best:  0.691
# Epochs: 70  | Train Loss:  0.641 | Train AUC:  0.619 | Valid AUC:  0.664  --best:  0.702
# Epochs: 80  | Train Loss:  0.646 | Train AUC:  0.623 | Valid AUC:  0.683  --best:  0.702
# Epochs: 90  | Train Loss:  0.629 | Train AUC:  0.633 | Valid AUC:  0.687  --best:  0.702
# Epochs: 100  | Train Loss:  0.630 | Train AUC:  0.626 | Valid AUC:  0.664  --best:  0.702
# Epochs: 110  | Train Loss:  0.620 | Train AUC:  0.631 | Valid AUC:  0.691  --best:  0.702
# Epochs: 120  | Train Loss:  0.615 | Train AUC:  0.637 | Valid AUC:  0.679  --best:  0.702
# Epochs: 130  | Train Loss:  0.629 | Train AUC:  0.639 | Valid AUC:  0.691  --best:  0.702
# Epochs: 140  | Train Loss:  0.622 | Train AUC:  0.644 | Valid AUC:  0.645  --best:  0.702
# early stopping at epoch: 149
# ====================
#
# *** training completed! ***

# %%
def inference(model: GCN, node_pair: tuple, THRESHOLD: float=0.5):
    torch.manual_seed(0)
    folder = '../SEAL_OGB/dataset/movie_actor'
    filename = 'movie_transformed.pt'
    data = torch.load(os.path.join(folder, filename))
    all_pos_edges = torch.cat([
        data.train_pos_edge_index,
        data.val_pos_edge_index,
        data.test_pos_edge_index
        ],
        dim=1
    )

    model.eval()
    node_ids = torch.tensor(list(range(data.num_nodes)))
    edge_label_index = torch.tensor([[node_pair[0]], [node_pair[1]]])
    logits = model(data.x, node_ids, all_pos_edges, edge_label_index)

    logits = Sigmoid()(logits.view(-1))
    logits[logits >= THRESHOLD] = 1
    logits[logits < THRESHOLD] = 0
    logits = logits.cpu().detach()
    model_inferred = int(logits[0].item())
    observed = 0
    mask_s = all_pos_edges[0] == node_pair[0]
    mask_t = all_pos_edges[1] == node_pair[1]
    mask = mask_s * mask_t
    if any(mask):
        observed = 1
    
    return observed, model_inferred

# %%
# start inference
model_name = 'model_checkpoint_final_model'
HIDDEN_CHANNEL = 64
NUM_LAYERS = 2
USE_GRAPH_STAT = False
DROPOUT = 0.3
model = GCN(HIDDEN_CHANNEL, NUM_LAYERS, USE_GRAPH_STAT, DROPOUT)
model_state = torch.load(os.path.join(MODEL_PATH, model_name))
model.load_state_dict(model_state)

node_pair = (1, 30)
observed, model_inferred = inference(model, node_pair)
print(f'observed: {observed} -> inferred: {model_inferred}')
# Out:
# observed: 0 -> inferred: 1

# %%
import json
data_path = '../datasets/actor_id_dict.json'
with open(data_path, 'r') as f:
    actor_id = json.load(f)
actor_id
# Out:
# {'AamirKhan': 0,
#  'AbhishekBachchan': 1,
#  'FatimaSanaShaikh': 2,
#  'HrithikRoshan': 3,
#  'BárbaraMori': 4,
#  'ShahRukhKhan': 5,
#  'RaniMukerji': 6,
#  'SalmanKhan': 7,
#  'KareenaKapoorKhan': 8,
#  'PreityZinta': 9,
#  'IrrfanKhan': 10,
#  'NimratKaur': 11,
#  'NaseeruddinShah': 12,
#  'LilleteDubey': 13,
#  'KatrinaKaif': 14,
#  'AnushkaSharma': 15,
#  'Siddharth': 16,
#  'RanbirKapoor': 17,
#  'DeepikaPadukone': 18,
#  'AkshayKumar': 19,
#  'ArjunRampal': 20,
#  'SumeetDarshanDobhal': 21,
#  'SaifAliKhan': 22,
#  'AbhayDeol': 23,
#  'EmraanHashmi': 24,
#  'AnilKapoor': 25,
#  'SunielShetty': 26,
#  'KarismaKapoor': 27,
#  'BipashaBasu': 28,
#  'HelenMirren': 29,
#  'JulieWalters': 30,
#  'MakrandDeshpande': 31,
#  'SachiinJoshi': 32,
#  'PaulWalker': 33,
#  'SteveZahn': 34,
#  'ChristianBale': 35,
#  'HeathLedger': 36,
#  'ElijahWood': 37,
#  'IanMcKellen': 38,
#  'MatthewMcConaughey': 39,
#  'AnneHathaway': 40,
#  'AdrienBrody': 41,
#  'ThomasKretschmann': 42,
#  'LeonardoDiCaprio': 43,
#  'JosephGordon-Levitt': 44,
#  'AntonioBanderas': 45,
#  'SalmaHayek': 46,
#  'HonorKneafsey': 47,
#  'EvaWhittaker': 48,
#  'HaleyLuRichardson': 49,
#  'ColeSprouse': 50,
#  'TomCruise': 51,
#  'MilesTeller': 52,
#  'AnneDorval': 53,
#  'AntoineOlivierPilon': 54,
#  'RobertDowneyJr.': 55,
#  'ChrisEvans': 56,
#  'ChrisHemsworth': 57,
#  'ViggoMortensen': 58,
#  'MahershalaAli': 59,
#  'MiloVentimiglia': 60,
#  'KevinCostner': 61,
#  'AnthonyGonzalez': 62,
#  'GaelGarcíaBernal': 63,
#  'BradPitt': 64,
#  'MélanieLaurent': 65,
#  'RussellCrowe': 66,
#  'JoaquinPhoenix': 67,
#  'HughJackman': 68,
#  'EmmaStone': 69,
#  'ViolaDavis': 70,
#  'MarkRuffalo': 71,
#  'AndrewGarfield': 72,
#  'SamWorthington': 73,
#  'GuyPearce': 74,
#  'Carrie-AnneMoss': 75,
#  'AmandlaStenberg': 76,
#  'ReginaHall': 77,
#  'ArmieHammer': 78,
#  'TimothéeChalamet': 79,
#  'JamieFoxx': 80,
#  'ChristophWaltz': 81,
#  'JacobTremblay': 82,
#  'JuliaRoberts': 83,
#  'AnthonyHopkins': 84,
#  'OliviaColman': 85,
#  'JimCarrey': 86,
#  'KateWinslet': 87,
#  'DanielDay-Lewis': 88,
#  'PaulDano': 89,
#  'LubnaAzabal': 90,
#  'MélissaDésormeaux-Poulin': 91,
#  'KeiraKnightley': 92,
#  'MatthewMacfadyen': 93,
#  'DevPatel': 94,
#  'RooneyMara': 95,
#  'JakeGyllenhaal': 96,
#  'BobOdenkirk': 97,
#  'ConnieNielsen': 98,
#  'TarajiP.Henson': 99,
#  'OctaviaSpencer': 100,
#  'RomanGriffinDavis': 101,
#  'ThomasinMcKenzie': 102,
#  'RalphFiennes': 103,
#  'F.MurrayAbraham': 104,
#  'BrendanFraser': 105,
#  'SadieSink': 106,
#  'MckennaGrace': 107,
#  'DouglasBooth': 108,
#  'EleanorTomlinson': 109,
#  'BrieLarson': 110,
#  'JonahHill': 111,
#  'EllenBurstyn': 112,
#  'JaredLeto': 113,
#  'KeanuReeves': 114,
#  'DonnieYen': 115,
#  'DanielRadcliffe': 116,
#  'RupertGrint': 117,
#  'TomHolland': 118,
#  'Zendaya': 119,
#  'BenedictCumberbatch': 120,
#  'RamiMalek': 121,
#  'GwilymLee': 122,
#  'EmiliaJones': 123,
#  'MarleeMatlin': 124,
#  'ClintEastwood': 125,
#  'ChristopherCarley': 126,
#  'GeorgeMacKay': 127,
#  'Dean-CharlesChapman': 128,
#  'MadelineCarroll': 129,
#  'CallanMcAuliffe': 130,
#  'HilarySwank': 131,
#  'ReeseWitherspoon': 132,
#  'ChiwetelEjiofor': 133,
#  'MichaelFassbender': 134,
#  'JessicaRothe': 135,
#  'HarryShumJr.': 136,
#  'CharliePlummer': 137,
#  'MollyParker': 138,
#  'EdAsner': 139,
#  'ChristopherPlummer': 140,
#  'JoshBrolin': 141,
#  'JavierBardem': 142,
#  'MichaelB.Jordan': 143,
#  'AmyPoehler': 144,
#  'PhyllisSmith': 145,
#  'ScottGlenn': 146,
#  'SamanthaIsler': 147,
#  'ChiaraMastroianni': 148,
#  'DanielleDarrieux': 149,
#  'ZacEfron': 150,
#  'EmiliaClarke': 151,
#  'SamClaflin': 152,
#  'DomhnallGleeson': 153,
#  'RachelMcAdams': 154,
#  'SaoirseRonan': 155,
#  'FlorencePugh': 156,
#  'WillSmith': 157,
#  'JadenSmith': 158,
#  'ChrisPratt': 159,
#  'ZoeSaldaña': 160,
#  'NataliePortman': 161,
#  'HugoWeaving': 162,
#  'BenAffleck': 163,
#  'RosamundPike': 164,
#  'RyanGosling': 165,
#  'YvonneStrahovski': 166,
#  'Björk': 167,
#  'CatherineDeneuve': 168,
#  'TomHanks': 169,
#  'MarianaTreviño': 170,
#  'VincentCassel': 171,
#  'RedaKateb': 172,
#  'MasakoNozawa': 173,
#  'AyaHisakawa': 174,
#  'BobTheCat': 175,
#  'LukeTreadaway': 176,
#  'EddieRedmayne': 177,
#  'FelicityJones': 178,
#  'ScarlettJohansson': 179,
#  'JenniferConnelly': 180,
#  'DanielCraig': 181,
#  'AsaButterfield': 182,
#  'JackScanlon': 183,
#  'JoelEdgerton': 184,
#  'TomHardy': 185,
#  'NaomiWatts': 186,
#  'LauraHarring': 187,
#  'FrédéricPierrot': 188,
#  'JoeyStarr': 189,
#  'SarahPolley': 190,
#  'AlbertBrooks': 191,
#  'EllenDeGeneres': 192,
#  'DakotaFanning': 193,
#  'TeriHatcher': 194,
#  'EthanHawke': 195,
#  'JulieDelpy': 196,
#  'DafneKeen': 197,
#  'EmileHirsch': 198,
#  'MarciaGayHarden': 199,
#  'MichaelKeaton': 200,
#  'KarenAbercrombie': 201,
#  'PriscillaC.Shirer': 202,
#  'JayBaruchel': 203,
#  'GerardButler': 204,
#  'BellaThorne': 205,
#  'PatrickSchwarzenegger': 206,
#  'RebeccaFerguson': 207,
#  'JasonStatham': 208,
#  'PattonOswalt': 209,
#  'IanHolm': 210,
#  'TimAllen': 211,
#  'JenaMalone': 212,
#  'OSheaJacksonJr.': 213,
#  'CoreyHawkins': 214,
#  'LoganLerman': 215,
#  'EmmaWatson': 216,
#  'GeorgeClooney': 217,
#  'MerylStreep': 218,
#  'ThusoMbedu': 219,
#  'GüneşNeziheŞensoy': 220,
#  'DoğaZeynepDoğuşlu': 221,
#  'MichaelCaine': 222,
#  'JohnGallagherJr.': 223,
#  'AmericaFerrera': 224,
#  'EwanMcGregor': 225,
#  'AlbertFinney': 226,
#  'Jean-LouisTrintignant': 227,
#  'EmmanuelleRiva': 228,
#  'AdamDriver': 229,
#  'AunjanueEllis': 230,
#  'SeanPenn': 231,
#  'TimRobbins': 232,
#  'JasonBateman': 233,
#  'GinniferGoodwin': 234,
#  'RizAhmed': 235,
#  'PaulRaci': 236,
#  'MandyMoore': 237,
#  'ShaneWest': 238,
#  'SamuelL.Jackson': 239,
#  'KurtRussell': 240,
#  'ScottAdsit': 241,
#  'RyanPotter': 242,
#  'SachaBaronCohen': 243,
#  'SaurabhShukla': 244,
#  'MikeMyers': 245,
#  'EddieMurphy': 246,
#  'RobertPattinson': 247,
#  'ZoëKravitz': 248,
#  'DonCheadle': 249,
#  'SophieOkonedo': 250,
#  'ReneRusso': 251,
#  'CraigT.Nelson': 252,
#  'HollyHunter': 253,
#  'MattDamon': 254,
#  'JamesCromwell': 255,
#  'SamNeill': 256,
#  'JulianDennison': 257,
#  'AlexanderSkarsgård': 258,
#  'MillieBobbyBrown': 259,
#  'JaredGilman': 260,
#  'KaraHayward': 261,
#  'SamRockwell': 262,
#  'MarcMaron': 263,
#  'CharlieHunnam': 264,
#  'SandraBullock': 265,
#  'TimMcGraw': 266,
#  'ZhangZiyi': 267,
#  'GongLi': 268,
#  'AlexKendrick': 269,
#  'BartoszBielenia': 270,
#  'AleksandraKonieczna': 271,
#  'HoltMcCallany': 272,
#  'JessicaChastain': 273,
#  'GregKinnear': 274,
#  'ToniCollette': 275,
#  'YalitzaAparicio': 276,
#  'MarinadeTavira': 277,
#  'CateBlanchett': 278,
#  'MilaKunis': 279,
#  'ChrissyMetz': 280,
#  'JoshLucas': 281,
#  'JamesMcAvoy': 282,
#  'HelenHunt': 283,
#  'JimCaviezel': 284,
#  'AustinButler': 285,
#  'StephanieBeatriz': 286,
#  'MaríaCeciliaBotero': 287,
#  'ArtParkinson': 288,
#  'CharlizeTheron': 289,
#  'DrewFuller': 290,
#  'AbigailBreslin': 291,
#  'TaronEgerton': 292,
#  'ColinFirth': 293,
#  'TerrenceHoward': 294,
#  'K.J.Apa': 295,
#  'BrittRobertson': 296,
#  'DenzelWashington': 297,
#  'WillPatton': 298,
#  'VanessaBauche': 299,
#  'SimuLiu': 300,
#  'TonyLeungChiu-wai': 301,
#  'RobertDeNiro': 302,
#  'AlPacino': 303,
#  'DanielKaluuya': 304,
#  'AllisonWilliams': 305,
#  'DaisyEdgar-Jones': 306,
#  'TaylorJohnSmith': 307,
#  'JeffBridges': 308,
#  'MackenzieFoy': 309,
#  'NicoleKidman': 310,
#  'ChristopherEccleston': 311,
#  'TyeSheridan': 312,
#  'OliviaCooke': 313,
#  'RosarioDawson': 314,
#  'JohnCho': 315,
#  'MichelleLa': 316,
#  'KirkCameron': 317,
#  'ErinBethea': 318,
#  'AliciaVikander': 319,
#  'AlexRoe': 320,
#  'WaltonGoggins': 321,
#  'CliveOwen': 322,
#  'JulianneMoore': 323,
#  'ShaileneWoodley': 324,
#  'AnselElgort': 325,
#  'RyanReynolds': 326,
#  'MorenaBaccarin': 327,
#  'TomHiddleston': 328,
#  'EmilyBlunt': 329,
#  'JamesMarsden': 330,
#  'BenSchwartz': 331,
#  'AngelinaJolie': 332,
#  'JohnMalkovich': 333,
#  'ScottEastwood': 334,
#  'MichaelPitt': 335,
#  'BritMarling': 336,
#  'JamieBell': 337,
#  'GaryLewis': 338,
#  'MargotRobbie': 339,
#  'IdrisElba': 340,
#  'AbrahamAttah': 341,
#  'PiperPerabo': 342,
#  'LenaHeadey': 343,
#  'ZacharyLevi': 344,
#  'AnthonyMackie': 345,
#  'AmyAdams': 346,
#  'JeremyRenner': 347,
#  'MartinFreeman': 348,
#  'KevinSpacey': 349,
#  'MichellePfeiffer': 350,
#  'HarrisonFord': 351,
#  'DanStevens': 352,
#  'AuliiCravalho': 353,
#  'DwayneJohnson': 354,
#  'KenWatanabe': 355,
#  'MarkWahlberg': 356,
#  'RoseByrne': 357,
#  'SteveCarell': 358,
#  'ThomasMann': 359,
#  'CatherineKeener': 360,
#  'RobBrown': 361,
#  'RudyYoungblood': 362,
#  'RaoulMaxTrujillo': 363,
#  'AshtonKutcher': 364,
#  'AmySmart': 365,
#  'DavidSpade': 366,
#  'JohnGoodman': 367,
#  'KenBevel': 368,
#  'SimonPegg': 369,
#  'NickFrost': 370,
#  'DavidHarbour': 371,
#  'JohnLeguizamo': 372,
#  'OwenWilson': 373,
#  'PatrickWilson': 374,
#  'VeraFarmiga': 375,
#  'AnyaTaylor-Joy': 376,
#  'CaseyAffleck': 377,
#  'LucasHedges': 378,
#  'RenéeZellweger': 379,
#  'TomKenny': 380,
#  'BillFagerbakke': 381,
#  'JaedenMartell': 382,
#  'EvaGreen': 383,
#  'MickeyRourke': 384,
#  'EvanRachelWood': 385,
#  'WillemDafoe': 386,
#  'DiegoLuna': 387,
#  'ChanningTatum': 388,
#  'BrianMurray': 389,
#  'JohnDavidWashington': 390,
#  'ChloeBennet': 391,
#  'AlbertTsai': 392,
#  'DjimonHounsou': 393,
#  'ChrisPine': 394,
#  'MichelleRodriguez': 395,
#  'JenniferJasonLeigh': 396,
#  'NicolasCage': 397,
#  'J.MichaelFinley': 398,
#  'DennisQuaid': 399,
#  'CarrieCoon': 400,
#  'FinnWolfhard': 401,
#  'JohnnyDepp': 402,
#  'HelenaBonhamCarter': 403,
#  'EllarColtrane': 404,
#  'PatriciaArquette': 405,
#  'ColinFarrell': 406,
#  'BrendanGleeson': 407,
#  'DaveighChase': 408,
#  'ChrisSanders': 409,
#  'SanaaLathan': 410,
#  'OmarEpps': 411,
#  'ShannenFields': 412,
#  'LoganMarshall-Green': 413,
#  'BettyGabriel': 414,
#  'JoeyKing': 415,
#  'AlecBaldwin': 416,
#  'JodieComer': 417,
#  'GeneHackman': 418,
#  'AnjelicaHuston': 419,
#  'SebastianStan': 420,
#  'BrankoĐurić': 421,
#  'ReneBitorajac': 422,
#  'PatrickFugit': 423,
#  'BillyCrudup': 424,
#  'GeoffreyRush': 425,
#  'SophieNélisse': 426,
#  'JunShison': 427,
#  'Riria': 428,
#  'RosalieChiang': 429,
#  'SandraOh': 430,
#  'PenélopeCruz': 431,
#  'CarmenMaura': 432,
#  'JoshHartnett': 433,
#  'MorganFreeman': 434,
#  'ScottMechlowicz': 435,
#  'NickNolte': 436,
#  'MichelleMonaghan': 437,
#  'JohnCameronMitchell': 438,
#  'MiriamShor': 439,
#  'FionnWhitehead': 440,
#  'KazunariNinomiya': 441,
#  'QueenLatifah': 442,
#  'BlakeLively': 443,
#  'MichielHuisman': 444,
#  'MarkStrong': 445,
#  'FrankaPotente': 446,
#  'Awkwafina': 447,
#  'ZhaoShuzhen': 448,
#  'KerryWashington': 449,
#  'MaiaMorgenstern': 450,
#  'PierreCoffin': 451,
#  'JenniferGarner': 452,
#  'KylieRogers': 453,
#  'IainArmitage': 454,
#  'LillyBartlam': 455,
#  'JackOConnell': 456,
#  'AlexRussell': 457,
#  'JeanDujardin': 458,
#  'BéréniceBejo': 459,
#  'CubaGoodingJr.': 460,
#  'PaulWalterHauser': 461,
#  'JonHamm': 462,
#  'BruceDern': 463,
#  'WillForte': 464,
#  'AlfredMolina': 465,
#  'BruceWillis': 466,
#  'JessicaAlba': 467,
#  'ForestWhitaker': 468,
#  'BradleyCooper': 469,
#  'SiennaMiller': 470,
#  'ZacharyQuinto': 471,
#  'EvanMcGuire': 472,
#  'ChristenMooney': 473,
#  'ElizabethOlsen': 474,
#  'DerekLuke': 475,
#  'TaylorKitsch': 476,
#  'JenniferLawrence': 477,
#  'JoshHutcherson': 478,
#  'SharltoCopley': 479,
#  'JasonCope': 480,
#  'JuliaStiles': 481,
#  'BrooklynnPrince': 482,
#  'ElizabethBanks': 483,
#  'JimSturgess': 484,
#  'ShiaLaBeouf': 485,
#  'ZackGottsagen': 486,
#  'PeterDinklage': 487,
#  'PatriciaClarkson': 488,
#  'SylvesterStallone': 489,
#  'CraigRoberts': 490,
#  'YasminPaige': 491,
#  'GretaGerwig': 492,
#  'MickeySumner': 493,
#  'StephenChow': 494,
#  'YuenWah': 495,
#  'MichaelNyqvist': 496,
#  'JohnKrasinski': 497,
#  'CareyMulligan': 498,
#  'JasonClarke': 499,
#  'TrevanteRhodes': 500,
#  'AndréHolland': 501,
#  'CaryElwes': 502,
#  'PaulModer': 503,
#  'BillMurray': 504,
#  'ChadwickBoseman': 505,
#  'SurajSharma': 506,
#  'StevenYeun': 507,
#  'HanYeri': 508,
#  'FreddieHighmore': 509,
#  'KeriRussell': 510,
#  'JudeLaw': 511,
#  'JosephFiennes': 512,
#  'BeniciodelToro': 513,
#  'LiamNeeson': 514,
#  'MaggieGrace': 515,
#  'ChloëGraceMoretz': 516,
#  'JamieBlackley': 517,
#  'TobeyMaguire': 518,
#  'LakeithStanfield': 519,
#  'PazdelaHuerta': 520,
#  'NathanielBrown': 521,
#  'CillianMurphy': 522,
#  'PádraicDelaney': 523,
#  'DianeLane': 524,
#  'NathanFillion': 525,
#  'SummerGlau': 526,
#  'JudiDench': 527,
#  'SteveCoogan': 528,
#  'MelonieDiaz': 529,
#  'DylanOBrien': 530,
#  'JessicaHenwick': 531,
#  'JaneAdams': 532,
#  'CynthiaErivo': 533,
#  'LeslieOdomJr.': 534,
#  'GaryOldman': 535,
#  'KristinScottThomas': 536,
#  'JonathanRhysMeyers': 537,
#  'EmmaThompson': 538,
#  'IsabelaMerced': 539,
#  'JesseEisenberg': 540,
#  'AnnetteBening': 541,
#  'LucasJadeZumann': 542,
#  'EdwardNorton': 543,
#  'PhilipSeymourHoffman': 544,
#  'ElleFanning': 545,
#  'BenWhishaw': 546,
#  'AlanRickman': 547,
#  'KumailNanjiani': 548,
#  'ZoeKazan': 549,
#  'RayRomano': 550,
#  'WoodyHarrelson': 551,
#  'MelissaBarrera': 552,
#  'JennaOrtega': 553,
#  'KatherineWaterston': 554,
#  'HayleyAtwell': 555,
#  'MelGibson': 556,
#  'CatherineZeta-Jones': 557,
#  'MalinÅkerman': 558,
#  'AndySamberg': 559,
#  'CristinMilioti': 560,
#  'JohnC.Reilly': 561,
#  'SarahSilverman': 562,
#  'MichaelPeña': 563,
#  'KitHarington': 564,
#  'JohnBoyega': 565,
#  'WillPoulter': 566,
#  'EdHelms': 567,
#  'ElliotPage': 568,
#  'RobertDuvall': 569,
#  'AnnaKendrick': 570,
#  'BrittanySnow': 571,
#  'MichaelSheen': 572,
#  'FrankLangella': 573,
#  'AhmadKhanMahmoodzada': 574,
#  'AtossaLeoni': 575,
#  'KatieHolmes': 576,
#  'ManishDayal': 577,
#  'AndySerkis': 578,
#  'HaileeSteinfeld': 579,
#  'TessaThompson': 580,
#  'VickyKrieps': 581,
#  'JeremyIrvine': 582,
#  'PeterMullan': 583,
#  'LetitiaWright': 584,
#  'LupitaNyongo': 585,
#  'TakeshiKaneshiro': 586,
#  'AndyLau': 587,
#  'AnaïsDemoustier': 588,
#  'AnnaSophiaRobb': 589,
#  'JamesFranco': 590,
#  'IdinaMenzel': 591,
#  'KristenBell': 592,
#  'EmmyRossum': 593,
#  'AnthonyRamos': 594,
#  'BryanCranston': 595,
#  'BridgetMoynahan': 596,
#  'LaurieMetcalf': 597,
#  'JamesBadgeDale': 598,
#  'ZooeyDeschanel': 599,
#  'AlexWolff': 600,
#  'JoshGad': 601,
#  'LewisMacDougall': 602,
#  'SigourneyWeaver': 603,
#  'OscarIsaac': 604,
#  'OliviaWilde': 605,
#  'AgataKulesza': 606,
#  'AgataTrzebuchowska': 607,
#  'WillFerrell': 608,
#  'MaggieGyllenhaal': 609,
#  'MadinaNalwanga': 610,
#  'DavidOyelowo': 611,
#  'JeremySuarez': 612,
#  'TomSturridge': 613,
#  'ChristinaRicci': 614,
#  'VinDiesel': 615,
#  'TimothySpall': 616,
#  'SallyHawkins': 617,
#  'DougJones': 618,
#  'DarbyCamp': 619,
#  'JackWhitehall': 620,
#  'KennethBranagh': 621,
#  'KevinKline': 622,
#  'JulianneHough': 623,
#  'JoshDuhamel': 624,
#  'ClaireDanes': 625,
#  'CharlieCox': 626,
#  'MileyCyrus': 627,
#  'FrancesMcDormand': 628,
#  'DavidStrathairn': 629,
#  'MaricelÁlvarez': 630,
#  'AngourieRice': 631,
#  'JusticeSmith': 632,
#  'JohnCena': 633,
#  'KateMcKinnon': 634,
#  'CatalinaSandinoMoreno': 635,
#  'GuiliedLopez': 636,
#  'HarrisDickinson': 637,
#  'CharlbiDean': 638,
#  'MonicaBellucci': 639,
#  'KirstenDunst': 640,
#  'HenryGolding': 641,
#  'BillSkarsgård': 642,
#  'MartonCsokas': 643,
#  'StephenDillane': 644,
#  'OakesFegley': 645,
#  'MarkRylance': 646,
#  'EllePeterson': 647,
#  'DakotaJohnson': 648,
#  'AntonYelchin': 649,
#  'JackBlack': 650,
#  'DustinHoffman': 651,
#  'MirandaCosgrove': 652,
#  'RupertFriend': 653,
#  'VictorPolster': 654,
#  'AriehWorthalter': 655,
#  'MarioGuerra': 656,
#  'LimaraMeneses': 657,
#  'MichaelCera': 658,
#  'PaulGiamatti': 659,
#  'HopeDavis': 660,
#  'RosaSalazar': 661,
#  'JamesCorden': 662,
#  'WillArnett': 663,
#  'ZachGalifianakis': 664,
#  'DenzelWhitaker': 665,
#  'JenniferAniston': 666,
#  'CharlotteGainsbourg': 667,
#  'DaneDeHaan': 668,
#  'JakobSalvati': 669,
#  'EmilyWatson': 670,
#  'ElsieFisher': 671,
#  'JoshHamilton': 672,
#  'ImeldaStaunton': 673,
#  'PhilDavis': 674,
#  'ValKilmer': 675,
#  'Cher': 676,
#  'ChristinaAguilera': 677,
#  'MaximGaudette': 678,
#  'SébastienHuberdeau': 679,
#  'TaraStrong': 680,
#  'AshleighBall': 681,
#  'AaronTaylor-Johnson': 682,
#  'Anne-MarieDuff': 683,
#  'JeffreyWright': 684,
#  'AnikaNoniRose': 685,
#  'BrunoCampos': 686,
#  'JeremyIrons': 687,
#  'JodieFoster': 688,
#  'TyreseGibson': 689,
#  'JohnCusack': 690,
#  'RayLiotta': 691,
#  'MariaBello': 692,
#  'LindsayLohan': 693,
#  'MarisaTomei': 694,
#  'BenKingsley': 695,
#  'JasonIsaacs': 696,
#  'JeremySumpter': 697,
#  'KayaScodelario': 698,
#  'JackNicholson': 699,
#  'AdamSandler': 700,
#  'KeishaCastle-Hughes': 701,
#  'RawiriParatene': 702,
#  'AaronEckhart': 703,
#  'BenStiller': 704,
#  'KristenWiig': 705,
#  'JackReynor': 706,
#  'SethRogen': 707,
#  'JosephineLangford': 708,
#  'HeroFiennesTiffin': 709,
#  'EmilyMortimer': 710,
#  'RichardJenkins': 711,
#  'HaazSleiman': 712,
#  'TakeshiKitano': 713,
#  'JodieTurner-Smith': 714,
#  'ZoeyDeutch': 715,
#  'EdSkrein': 716,
#  'KylieghCurran': 717,
#  'AnthonyAnderson': 718,
#  'OrlandoBloom': 719,
#  'IbenHjejle': 720,
#  'ElisabethMoss': 721,
#  'AldisHodge': 722,
#  'EricBana': 723,
#  'Jean-ClaudeDreyfus': 724,
#  'KekePalmer': 725,
#  'JasonSudeikis': 726,
#  'JohnOliver': 727,
#  'AshleyJudd': 728,
#  'KevinHart': 729,
#  'TriesteKellyDunn': 730,
#  'StarlaBenford': 731,
#  'Eminem': 732,
#  'MekhiPhifer': 733,
#  'RicksonTevez': 734,
#  'EduardoLuís': 735,
#  'DavidThewlis': 736,
#  'LiamJames': 737,
#  'PaddyConsidine': 738,
#  'GaryStretch': 739,
#  'MenaMassoud': 740,
#  'RobertRedford': 741,
#  'JamesGandolfini': 742,
#  'AlexanderPetrov': 743,
#  'VictorDobronravov': 744,
#  'DaveFranco': 745,
#  'TaylorSchilling': 746,
#  'ConnorJessup': 747,
#  'AaronAbrams': 748,
#  'PaulBettany': 749,
#  'EmiliedeRavin': 750,
#  'NickOfferman': 751,
#  'ShameikMoore': 752,
#  'KierseyClemons': 753,
#  'BillNighy': 754,
#  'LewisTan': 755,
#  'JessicaMcNamee': 756,
#  'AlexFrost': 757,
#  'EricDeulen': 758,
#  'GolshiftehFarahani': 759,
#  'ZachBraff': 760,
#  'LLCoolJ': 761,
#  'MelissaMcCarthy': 762,
#  'HaydenChristensen': 763,
#  'ThoraBirch': 764,
#  'SteveBuscemi': 765,
#  'SeanConnery': 766,
#  'JimmieFails': 767,
#  'JonathanMajors': 768,
#  'KeiKobayashi': 769,
#  'YukaImoto': 770,
#  'ThomasHadenChurch': 771,
#  'JoshWiggins': 772,
#  'AnadelaReguera': 773,
#  'TenochHuertaMejía': 774,
#  'JohnRobinson': 775,
#  'PaulRudd': 776,
#  'MichaelDouglas': 777,
#  'ConstanceWu': 778,
#  'RachelZegler': 779,
#  'CameronDiaz': 780,
#  'ZhaoWei': 781,
#  'RayWinstone': 782,
#  'DanielAuteuil': 783,
#  'JulietteBinoche': 784,
#  'AlisonLohman': 785,
#  'HughBonneville': 786,
#  'AmberTamblyn': 787,
#  'JoanCusack': 788,
#  'SamaraWeaving': 789,
#  'AdamBrody': 790,
#  'FelicityHuffman': 791,
#  'KevinZegers': 792,
#  'EmmaRoberts': 793,
#  'DenisLavant': 794,
#  'EdithScob': 795,
#  'MatthiasSchoenaerts': 796,
#  'JohnnyFlynn': 797,
#  'MichaelShannon': 798,
#  'ClaireFoy': 799,
#  'RachelWeisz': 800,
#  'KaitlynDever': 801,
#  'BeanieFeldstein': 802,
#  'LaurenceFishburne': 803,
#  'AaronPaul': 804,
#  'VingRhames': 805,
#  'EmilyBrowning': 806,
#  'PeterSallis': 807,
#  'BillyCrystal': 808,
#  'TayeDiggs': 809,
#  'AlanaHaim': 810,
#  'CooperHoffman': 811,
#  'TildaSwinton': 812,
#  'AmandaSeyfried': 813,
#  'RaineyQualley': 814,
#  'VincentGallo': 815,
#  'JonnyWeston': 816,
#  'LauraDern': 817,
#  'JimBroadbent': 818,
#  'LesleyManville': 819,
#  'MattKing': 820,
#  'KellyMacdonald': 821,
#  'BillyConnolly': 822,
#  'BruceGreenwood': 823,
#  'DavidMcCullough': 824,
#  'HelenaZengel': 825,
#  'MatthewRhys': 826,
#  'NicholasHoult': 827,
#  'LilyCollins': 828,
#  'Xzibit': 829,
#  'PeterSarsgaard': 830,
#  'DanCastellaneta': 831,
#  'JulieKavner': 832,
#  'KeirGilchrist': 833,
#  'LiamHemsworth': 834,
#  'KatieJarvis': 835,
#  'PatrickStewart': 836,
#  'KodiSmit-McPhee': 837,
#  'TommyLeeJones': 838,
#  'AndréWilms': 839,
#  'KatiOutinen': 840,
#  'CameronBright': 841,
#  'StanleyTucci': 842,
#  'TatianaMaslany': 843,
#  'GemmaChan': 844,
#  'RichardMadden': 845,
#  'NigelLindsay': 846,
#  'HalstonSage': 847,
#  'WinstonDuke': 848,
#  'MaryElizabethWinstead': 849,
#  'MichaelJ.Fox': 850,
#  'CreeSummer': 851,
#  'VinceVaughn': 852,
#  'JenniferCarpenter': 853,
#  'ViveikKalra': 854,
#  'NellWilliams': 855,
#  'KiKiLayne': 856,
#  'StephanJames': 857,
#  'MaxMinghella': 858,
#  'BillPaxton': 859,
#  'JeffDaniels': 860,
#  'LauraLinney': 861,
#  'DakotaGoyo': 862,
#  'AsherAngel': 863,
#  'EverlynSampi': 864,
#  'TiannaSansbury': 865,
#  'EugenioDerbez': 866,
#  'JoshHolloway': 867,
#  'JoshPeck': 868,
#  'NatashaLyonne': 869,
#  'CleaDuVall': 870,
#  'EvangelineLilly': 871,
#  'ShaunaMacdonald': 872,
#  'NatalieMendoza': 873,
#  'EvaMendes': 874,
#  'TuckerAlbrizzi': 875,
#  'JustinTimberlake': 876,
#  'AmandaSchull': 877,
#  'CharlieTahan': 878,
#  'TomWilkinson': 879,
#  'ShannynSossamon': 880,
#  'IbrahimAhmed': 881,
#  'ToulouKiki': 882,
#  'GuguMbatha-Raw': 883,
#  'NateParker': 884,
#  'TinaFey': 885,
#  'GabrielBateman': 886,
#  'MaggieSmith': 887,
#  'AndyGarcía': 888,
#  'JuliannaMargulies': 889,
#  'SverrirGudnason': 890,
#  'MichelleWilliams': 891,
#  'LaurenLaVera': 892,
#  'DavidHowardThornton': 893,
#  'CatherineOHara': 894,
#  'SissySpacek': 895,
#  'KateBeckinsale': 896,
#  'JamalWoolard': 897,
#  'JulieAndrews': 898,
#  'PierceBrosnan': 899,
#  'JackieChan': 900,
#  'MelissaGeorge': 901,
#  'GwynethPaltrow': 902,
#  'BryceDallasHoward': 903,
#  'IsaachDeBankolé': 904,
#  'RobinWilliams': 905,
#  'BillyBobThornton': 906,
#  'LucasBlack': 907,
#  'LivTyler': 908,
#  'MiaMichaels': 909,
#  'MeganBoone': 910,
#  'TheoJames': 911,
#  'JohnHawkes': 912,
#  'JacobPerez': 913,
#  'HarryMaldonado': 914,
#  'LiuYifei': 915,
#  'ShawnWayans': 916,
#  'MarlonWayans': 917,
#  'LarrytheCableGuy': 918,
#  'GeorginaCampbell': 919,
#  'GriffinGluck': 920,
#  'LaurenGraham': 921,
#  'LakeBell': 922,
#  'BrianOHalloran': 923,
#  'JeffAnderson': 924,
#  'RalphIneson': 925,
#  'AlexPettyfer': 926,
#  'GabriellaWilde': 927,
#  'ColumbusShort': 928,
#  'MeaganGood': 929,
#  'JohnCleese': 930,
#  'JimCummings': 931,
#  'SummerPhoenix': 932,
#  'HarveyKeitel': 933,
#  'LeBronJames': 934,
#  'SongKang-ho': 935,
#  'JasonMomoa': 936,
#  'AmberHeard': 937,
#  'DaveBautista': 938,
#  'ChloeColeman': 939,
#  'RuthWilson': 940,
#  'MikeVogel': 941,
#  'ErikaChristensen': 942,
#  'AudreyTautou': 943,
#  'AdamDeVine': 944,
#  'AlexandraShipp': 945,
#  'RupertEverett': 946,
#  'ThomasJane': 947,
#  'LaurieHolden': 948,
#  'ChrisRock': 949,
#  'MatthewFox': 950,
#  'AdamBousdoukos': 951,
#  'BirolÜnel': 952,
#  'MichaelEaly': 953,
#  'JerryFerrara': 954,
#  'JennaDewan': 955,
#  'NickCannon': 956,
#  'MichaelGambon': 957,
#  'HalleBerry': 958,
#  'PresleyChweneyagae': 959,
#  'JerryMofokeng': 960,
#  'AnnabelleWallis': 961,
#  'MaddieHasson': 962,
#  'MichelleYeoh': 963,
#  'JungWoo-sung': 964,
#  'JulietRylance': 965,
#  'JenniferLopez': 966,
#  'SallyField': 967,
#  'RinkoKikuchi': 968,
#  'NoahSchnapp': 969,
#  'BillMelendez': 970,
#  'DrewBarrymore': 971,
#  'NeelSethi': 972,
#  'BradyNoon': 973,
#  'CristelaAlonzo': 974,
#  'JillianEstell': 975,
#  'SarahWright': 976,
#  'NaomieHarris': 977,
#  'KeikoAizawa': 978,
#  'AikoHibi': 979,
#  'BobBalaban': 980,
#  'ChristopherGuest': 981,
#  'AnthonyRapp': 982,
#  'AdamPascal': 983,
#  'AntonythasanJesuthasan': 984,
#  'KalieaswariSrinivasan': 985,
#  'RoryCulkin': 986,
#  'Lucy': 987,
#  'KieferSutherland': 988,
#  'BurtYoung': 989,
#  'PaulaPatton': 990,
#  'RadhaMitchell': 991,
#  'KhleoThomas': 992,
#  'SteveSandvoss': 993,
#  'WesRamsey': 994,
#  'KathyBates': 995,
#  'QuvenzhanéWallis': 996,
#  'DwightHenry': 997,
#  'RyanPhillippe': 998,
#  'AdamBeach': 999,
#  ...}
